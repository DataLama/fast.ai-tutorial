# %% [markdown]
# # The data block API
#
# data block API를 활용하면 lets you customize the creation of a DataBunch by isolating the underlying parts of that proces in seperate blocks.
#
# 1. Where the inputs and how to create them?
# 2. How to split the data into a training and validation sets?
# 3. How to label the inputs?
# 4. What transforms to apply?
# 5. How to add a test set?
# 6. How to wrap in dataloaders and create the DataBunch?

# %% [markdown]
# > DataBunch는 collection of dataloaders(train, validation, test)

# %%
import fastai.vision as fcv

# %% [markdown]
# - fastai의 간단한 파일 구조를 살펴보자.

# %% [markdown]
# - `/root/.fastai`가 기본 구조 $\longrightarrow$ 이거 커스텀 가능?
# - `config.yml`을 살펴보면, 크게 data_path와 model_path로 구분함.

# %%
# !ls /root/.fastai
# Out:
# config.yml  data  models

# %%
# !cat /root/.fastai/config.yml
# Out:
# data_archive_path: /root/.fastai/data
# data_path: /root/.fastai/data
# model_path: /root/.fastai/models

# %% [markdown]
# ## MNIST

# %% [markdown]
# - binary classification
# - data 아래에 task와 관련된 경로 생성.

# %%
## download and path
path = fcv.untar_data(fcv.URLs.MNIST_TINY)
path
# Out:
# Downloading http://files.fast.ai/data/examples/mnist_tiny
# PosixPath('/root/.fastai/data/mnist_tiny')

# %% [markdown]
# - data 안에 train/valid/test 셋만 나눔.
# - MNIST 데이터 구조는 ImageNet 데이터셋 구조로 이루어짐. (폴더에 label이 있음.)

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_tiny/train'),
#  PosixPath('/root/.fastai/data/mnist_tiny/test'),
#  PosixPath('/root/.fastai/data/mnist_tiny/labels.csv'),
#  PosixPath('/root/.fastai/data/mnist_tiny/valid'),
#  PosixPath('/root/.fastai/data/mnist_tiny/models')]

# %%
(path / 'train').ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_tiny/train/7'),
#  PosixPath('/root/.fastai/data/mnist_tiny/train/3')]

# %%
(path / 'valid').ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_tiny/valid/7'),
#  PosixPath('/root/.fastai/data/mnist_tiny/valid/3')]

# %%
(path / 'test').ls()[:5]
# Out:
# [PosixPath('/root/.fastai/data/mnist_tiny/test/3848.png'),
#  PosixPath('/root/.fastai/data/mnist_tiny/test/1503.png'),
#  PosixPath('/root/.fastai/data/mnist_tiny/test/617.png'),
#  PosixPath('/root/.fastai/data/mnist_tiny/test/1605.png'),
#  PosixPath('/root/.fastai/data/mnist_tiny/test/585.png')]

# %%
(path / 'model').ls() # 이 새끼 뭐하지?
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-f8b46e5261a8> in <module>
# ----> 1 (path / 'model').ls() # 이 새끼 뭐하지?
#
# /usr/local/lib/python3.6/dist-packages/fastai/core.py in <lambda>(x)
#     237     return np.arange(len(x))
#     238
# --> 239 Path.ls = lambda x: list(x.iterdir())
#     240
#     241 def join_path(fname:PathOrStr, path:PathOrStr='.')->Path:
#
# /usr/lib/python3.6/pathlib.py in iterdir(self)
#    1079         if self._closed:
#    1080             self._raise_closed()
# -> 1081         for name in self._accessor.listdir(self):
#    1082             if name in {'.', '..'}:
#    1083                 # Yielding a path object for these makes little sense
#
# /usr/lib/python3.6/pathlib.py in wrapped(pathobj, *args)
#     385         @functools.wraps(strfunc)
#     386         def wrapped(pathobj, *args):
# --> 387             return strfunc(str(pathobj), *args)
#     388         return staticmethod(wrapped)
#     389
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.fastai/data/mnist_tiny/model'

# %% [markdown]
# ### DataBunch
# - dataloader들의 뭉치임.
# - 예제 데이터의 경우 short_cut으로 databunch를 구성할 수 있음.

# %%
tfms = fcv.get_transforms(do_flip=False)
data = fcv.ImageDataBunch.from_folder(path, ds_tfms=tfms, size=64) # path는 프로젝트 경로, ds_tfms은 적용할 transform, size는 배치사이즈.

# %% [markdown]
# ### data block API
# - DataBunch를 커스텀 가능하게 구성할 수 있음.
# - 위의 6가지 기능을 독립적으로 구현 가능.

# %%
data = (fcv.ImageList.from_folder(path) # 1. Where to find the data? -> in path and its subfolders
        .split_by_folder()              # 2. How to split in train/valid? -> use the folders
        .label_from_folder()            # 3. How to label? -> depending on the folder of the filenames
        .add_test_folder()              # 4. Optionally add a test set (here default name is test)
        .transform(tfms, size=64)       # 5. Data augmentation? -> use tfms with a size of 64
        .databunch())                   # 6. Finally? -> use the defaults for conversion to ImageDataBunch

# %%
data.show_batch(3, figsize=(6,6), hide_axis=False)

# %% [markdown]
# ## Planet Data

# %% [markdown]
# - multiclassification

# %%
planet = fcv.untar_data(fcv.URLs.PLANET_TINY)

# %% [markdown]
# - train set과 label만 있음.

# %%
planet.ls()
# Out:
# [PosixPath('/root/.fastai/data/planet_tiny/train'),
#  PosixPath('/root/.fastai/data/planet_tiny/labels.csv')]

# %%
(planet / 'train').ls()[:4]
# Out:
# [PosixPath('/root/.fastai/data/planet_tiny/train/train_19125.jpg'),
#  PosixPath('/root/.fastai/data/planet_tiny/train/train_14593.jpg'),
#  PosixPath('/root/.fastai/data/planet_tiny/train/train_821.jpg'),
#  PosixPath('/root/.fastai/data/planet_tiny/train/train_38934.jpg')]

# %% [markdown]
# - multi_label classification 문제임.

# %%
import pandas as pd
pd.read_csv(planet / "labels.csv").head()
# Out:
#     image_name                            tags
# 0  train_31112                   clear primary
# 1   train_4300     partly_cloudy primary water
# 2  train_39539             clear primary water
# 3  train_12498  agriculture clear primary road
# 4   train_9320                   clear primary

# %%
planet_tfms = fcv.get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %%
data = (fcv.ImageList.from_csv(path=planet, csv_name='labels.csv', folder='train', suffix='.jpg') 
        #Where to find the data? -> in planet 'train' folder
        .split_by_rand_pct()
        #How to split in train/valid? -> randomly with the default 20% in valid
        .label_from_df(label_delim=' ')
        #How to label? -> use the second column of the csv file and split the tags by ' '
        .transform(planet_tfms, size=128)
        #Data augmentation? -> use tfms with a size of 128
        .databunch())                          
        #Finally -> use the defaults for conversion to databunch

# %%
data.show_batch(rows=2, figsize=(9,7))

# %% [markdown]
# ## Camvid

# %% [markdown]
# Segmentation $\Longrightarrow$ data block API를 잘 사용하면, databunch를 커스텀하기 좋음.

# %%
camvid = fcv.untar_data(fcv.URLs.CAMVID_TINY)
# Out:
# Downloading http://files.fast.ai/data/examples/camvid_tiny

# %%
camvid.ls()
# Out:
# [PosixPath('/root/.fastai/data/camvid_tiny/images'),
#  PosixPath('/root/.fastai/data/camvid_tiny/codes.txt'),
#  PosixPath('/root/.fastai/data/camvid_tiny/labels')]

# %%
(camvid / 'images').ls()[:5]
# Out:
# [PosixPath('/root/.fastai/data/camvid_tiny/images/0016E5_08370.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/images/Seq05VD_f02640.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/images/Seq05VD_f04950.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/images/Seq05VD_f03150.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/images/0001TP_009360.png')]

# %%
## mask?
(camvid / 'labels').ls()[:5]
# Out:
# [PosixPath('/root/.fastai/data/camvid_tiny/labels/Seq05VD_f02880_P.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/labels/Seq05VD_f00420_P.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/labels/0016E5_06240_P.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/labels/Seq05VD_f00210_P.png'),
#  PosixPath('/root/.fastai/data/camvid_tiny/labels/Seq05VD_f00090_P.png')]

# %%
## class
import numpy as np
codes = np.loadtxt(camvid/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %%
path_lbl = camvid/'labels'
path_img = camvid/'images'

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
path_lbl
# Out:
# PosixPath('/root/.fastai/data/camvid_tiny/labels')

# %%
path_img
# Out:
# PosixPath('/root/.fastai/data/camvid_tiny/images')

# %%
data = (fcv.SegmentationItemList.from_folder(path_img)
        #Where to find the data? -> in path_img and its subfolders
        .split_by_rand_pct()
        #How to split in train/valid? -> randomly with the default 20% in valid
        .label_from_func(get_y_fn, classes=codes)
        #How to label? -> use the label function on the file name of the data
        .transform(fcv.get_transforms(), tfm_y=True, size=128)
        #Data augmentation? -> use tfms with a size of 128, also transform the label images
        .databunch())
        #Finally -> use the defaults for conversion to databunch

# %%
data.show_batch(rows=2, figsize=(7,5))

# %% [markdown]
# ## Coco Dataset

# %% [markdown]
# - object detection

# %%
import json

# %% [markdown]
# - path

# %%
coco = fcv.untar_data(fcv.URLs.COCO_TINY)
coco
# Out:
# PosixPath('/root/.fastai/data/coco_tiny')

# %%
coco.ls()
# Out:
# [PosixPath('/root/.fastai/data/coco_tiny/train'),
#  PosixPath('/root/.fastai/data/coco_tiny/train.json')]

# %% [markdown]
# - decribe the data

# %%
with open(coco / 'train.json') as f:
    label = json.load(f)

# %%
label.keys()
# Out:
# dict_keys(['categories', 'images', 'annotations'])

# %%
label['categories']
# Out:
# [{'id': 62, 'name': 'chair'},
#  {'id': 63, 'name': 'couch'},
#  {'id': 72, 'name': 'tv'},
#  {'id': 75, 'name': 'remote'},
#  {'id': 84, 'name': 'book'},
#  {'id': 86, 'name': 'vase'}]

# %%
label['images'][:5]
# Out:
# [{'id': 542959, 'file_name': '000000542959.jpg'},
#  {'id': 129739, 'file_name': '000000129739.jpg'},
#  {'id': 153607, 'file_name': '000000153607.jpg'},
#  {'id': 329258, 'file_name': '000000329258.jpg'},
#  {'id': 452866, 'file_name': '000000452866.jpg'}]

# %%
label['annotations'][:5]
# Out:
# [{'image_id': 542959, 'bbox': [32.52, 86.34, 8.53, 9.41], 'category_id': 62},
#  {'image_id': 542959, 'bbox': [98.12, 110.52, 1.95, 4.07], 'category_id': 86},
#  {'image_id': 542959, 'bbox': [91.28, 51.62, 3.95, 5.72], 'category_id': 86},
#  {'image_id': 542959,
#   'bbox': [110.48, 110.82, 14.55, 15.22],
#   'category_id': 62},
#  {'image_id': 542959, 'bbox': [96.63, 50.18, 18.67, 13.46], 'category_id': 62}]

# %%
(coco /'train').ls()[:3]
# Out:
# [PosixPath('/root/.fastai/data/coco_tiny/train/000000283257.jpg'),
#  PosixPath('/root/.fastai/data/coco_tiny/train/000000461908.jpg'),
#  PosixPath('/root/.fastai/data/coco_tiny/train/000000375980.jpg')]

# %% [markdown]
# - data block

# %%
len(images)
# Out:
# 200

# %%
lbl_bbox[0]
# Out:
# [[[86.34, 32.52, 95.75, 41.050000000000004],
#   [110.52, 98.12, 114.59, 100.07000000000001],
#   [51.62, 91.28, 57.339999999999996, 95.23],
#   [110.82, 110.48, 126.03999999999999, 125.03],
#   [50.18, 96.63, 63.64, 115.3],
#   [111.73, 0.69, 124.79, 12.49]],
#  ['chair', 'vase', 'vase', 'chair', 'chair', 'chair']]

# %%
images, lbl_bbox = fcv.get_annotations(coco/'train.json')
img2bbox = dict(zip(images, lbl_bbox))
get_y_func = lambda o:img2bbox[o.name]

# %%
data = (fcv.ObjectItemList.from_folder(coco)
        #Where are the images? -> in coco and its subfolders
        .split_by_rand_pct()                          
        #How to split in train/valid? -> randomly with the default 20% in valid
        .label_from_func(get_y_func)
        #How to find the labels? -> use get_y_func on the file name of the data
        .transform(fcv.get_transforms(), tfm_y=True)
        #Data augmentation? -> Standard transforms; also transform the label images
        .databunch(bs=16, collate_fn=fcv.bb_pad_collate))   
        #Finally we convert to a DataBunch, use a batch size of 16,
        # and we use bb_pad_collate to collate the data into a mini-batch

# %%
data.show_batch(rows=2, ds_type=fcv.DatasetType.Valid, figsize=(6,6))
